# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("stock.db")
df = pd.read_sql_query(
    """
                        SELECT stock_code AS stock_code,
                               stock_factor AS stock_factor,
                               stock_year AS stock_year,
                               stock_data AS stock_data
                          FROM vcsc_financial_ratio
                         WHERE stock_factor = 'EPS (VND)'
                         GROUP BY stock_code,
                                  stock_factor,
                                  stock_year,
                                  stock_data;           
                        """, conn)

df2 = pd.read_sql_query(
    """
                        select STOCK_CODE, STOCK_DATE, STOCK_CLOSE from vcsc_stock_price;
                        """, conn)


df2['STOCK_DATE'] = pd.to_datetime(df2['STOCK_DATE'], format='%m/%d/%Y')

df2['YEAR'] = df2['STOCK_DATE'].dt.year
df2['MONTH'] = df2['STOCK_DATE'].dt.month
df2['DAY'] = df2['STOCK_DATE'].dt.day

df2

#df.pivot(index='stock_code', columns='stock_year', values='stock_data')
#conn.close()
# Out:
#         STOCK_CODE STOCK_DATE STOCK_CLOSE  YEAR  MONTH  DAY
# 0              ACV 2017-05-03      48,732  2017      5    3
# 1              ACV 2017-04-28      49,178  2017      4   28
# 2              ACV 2017-04-27      49,595  2017      4   27
# 3              ACV 2017-04-26      49,496  2017      4   26
# 4              ACV 2017-04-25      48,593  2017      4   25
# 5              ACV 2017-04-24      48,980  2017      4   24
# 6              ACV 2017-04-21      49,228  2017      4   21
# 7              ACV 2017-04-20      49,555  2017      4   20
# 8              ACV 2017-04-19      49,119  2017      4   19
# 9              ACV 2017-04-18      49,456  2017      4   18
# 10             ACV 2017-04-17      49,605  2017      4   17
# 11             ACV 2017-04-14      49,506  2017      4   14
# 12             ACV 2017-04-13      49,744  2017      4   13
# 13             ACV 2017-04-12      49,655  2017      4   12
# 14             ACV 2017-04-11      49,922  2017      4   11
# ...
